# %%
#Author: Yuanzong Zhang, Jun Zhang#
import numpy as np
import pandas as pd
from sklearn import preprocessing
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Bidirectional
from keras.models import Model

# %%
#!/usr/bin/env Python
# coding=utf-8

df = pd.read_csv('Data_tai_lake.csv')
df.head()
# Out:
#      pH     TN     TP  Chlorophy  DeMgChlorophy  Permanganate      AN     NN  \
# 0  7.70  10.23  0.430       5.00           3.31          8.73   2.854  0.156
# 1  7.76   7.32  0.583       9.29           1.68          5.18   3.692  0.110
# 2  7.79  12.74  0.493      19.15           8.88          9.89  10.010  0.161
# 3  7.68  10.80  0.350      37.75          10.78          9.71   4.071  0.166
# 4  7.65  11.20  0.323      96.42          21.90          9.53   3.864  0.279
#
#    Ni-nitr  DissolvedN        ...         alkalinity    PI    SI    CI     MI  \
# 0    2.279         NaN        ...               2.79  7.16  55.1  42.1  11.44
# 1    2.021         NaN        ...               2.41  5.60  42.0  36.3   9.48
# 2    2.399         NaN        ...               3.35  7.90  91.6  36.4  12.86
# 3    2.420         NaN        ...               2.88  4.85  70.2  28.6   8.64
# 4    4.021         NaN        ...               2.50  5.22  54.4  39.5   8.59
#
# ...

# %%
print ('Variance of DO: ', df['dissolved-oxygen'].var())
print ('Mean of DO: ', df['dissolved-oxygen'].mean())
# Out:
# Variance of DO:  7.981873193758521
# Mean of DO:  8.182543554006969

# %%
df = df.fillna(df.mean())
df
# Out:
#        pH     TN     TP  Chlorophy  DeMgChlorophy  Permanganate      AN  \
# 0    7.70  10.23  0.430       5.00           3.31          8.73   2.854
# 1    7.76   7.32  0.583       9.29           1.68          5.18   3.692
# 2    7.79  12.74  0.493      19.15           8.88          9.89  10.010
# 3    7.68  10.80  0.350      37.75          10.78          9.71   4.071
# 4    7.65  11.20  0.323      96.42          21.90          9.53   3.864
# 5    7.40   9.34  0.223      26.08           4.67          7.04   3.101
# 6    7.78   5.71  0.328      35.51           4.13          7.07   3.460
# 7    7.70   3.06  0.175      62.85          18.95          7.41   0.535
# 8    8.15   1.04  0.182      46.10           3.50          5.87   0.034
# 9    7.70   7.47  0.288      13.30           5.90          6.29   5.288
# 10   7.87  10.20  0.278      14.23           6.28          6.81   7.524
# 11   7.60   8.93  0.306       2.14           7.86          7.98   5.400
# ...

# %%
x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_scaled = pd.DataFrame(x_scaled)
df_scaled
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.326271  0.747153  0.192125  0.009584  0.057039  0.419153  0.284901
# 1    0.351695  0.526196  0.264706  0.017806  0.028951  0.172797  0.368642
# 2    0.364407  0.937737  0.222011  0.036705  0.153024  0.499653  1.000000
# 3    0.317797  0.790433  0.154175  0.072355  0.185766  0.487162  0.406515
# 4    0.305085  0.820805  0.141366  0.184808  0.377391  0.474670  0.385830
# 5    0.199153  0.679575  0.093928  0.049988  0.080476  0.301874  0.309583
# 6    0.360169  0.403948  0.143738  0.068062  0.071170  0.303956  0.345458
# 7    0.326271  0.202733  0.071157  0.120465  0.326555  0.327550  0.053163
# 8    0.516949  0.049355  0.074478  0.088360  0.060314  0.220680  0.003098
# 9    0.326271  0.537585  0.124763  0.025492  0.101672  0.249827  0.528130
# 10   0.398305  0.744875  0.120019  0.027275  0.108220  0.285913  0.751574
# 11   0.283898  0.648443  0.133302  0.004102  0.135447  0.367106  0.539322
# ...

# %%
x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_scaled = pd.DataFrame(x_scaled)
df_scaled
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.326271  0.747153  0.192125  0.419153  0.284901  0.022305  0.532367
# 1    0.351695  0.526196  0.264706  0.172797  0.368642  0.015686  0.472073
# 2    0.364407  0.937737  0.222011  0.499653  1.000000  0.023025  0.560411
# 3    0.317797  0.790433  0.154175  0.487162  0.406515  0.023744  0.565319
# 4    0.305085  0.820805  0.141366  0.474670  0.385830  0.040006  0.939472
# 5    0.199153  0.679575  0.093928  0.301874  0.309583  0.025471  1.000000
# 6    0.360169  0.403948  0.143738  0.303956  0.345458  0.026335  0.164291
# 7    0.326271  0.202733  0.071157  0.327550  0.053163  0.038279  0.196775
# 8    0.516949  0.049355  0.074478  0.220680  0.003098  0.001871  0.008179
# 9    0.326271  0.537585  0.124763  0.249827  0.528130  0.021010  0.125964
# 10   0.398305  0.744875  0.120019  0.285913  0.751574  0.028637  0.148633
# 11   0.283898  0.648443  0.133302  0.367106  0.539322  0.026335  0.299603
# ...

# %%
# Feature engineering function to define time series data
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# Small Lstms for forcasting the features in the target timeline.
step_size = 3
y_predict = []
n_features = 1

for indx in df_scaled.columns:
    X, y = split_sequence(df_scaled[indx], step_size)
#     print (X.shape)
    X_train = X[0:X.shape[0], :]
    y_train = y[0:X.shape[0]]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
    # define model
    model = Sequential()
    model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(step_size, n_features)))
#     model.add(LSTM(50, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    # fit model
    model.fit(X_train, y_train, epochs=200, verbose=0)
    # demonstrate prediction
    x_input = X_train[-1]
    x_input = x_input.reshape((1, step_size, n_features))
    yhat = model.predict(x_input, verbose=0)
    y_predict.append(yhat)
    print (x_input)
    print (yhat)
print (y_predict)
# 0.542373	0.148823	0.036053	0.012171	0.002585	0.176960	0.015689	0.005756	0.149334	0.112283
# Out:
# [[[0.49152542]
#   [0.59322034]
#   [0.56355932]]]
# [[0.5629217]]
# [[[0.08883827]
#   [0.06909643]
#   [0.07289294]]]
# [[0.11308458]]
# [[[0.04127135]
#   [0.02609108]
#   [0.03462998]]]
# [[0.03762695]]
# [[[0.01924367]
#   [0.00854848]
#   [0.00642095]]]
# [[0.01817152]]
# [[[0.00189557]
#   [0.00930553]
#   [0.0230915 ]]]
# [[0.03560275]]
# [[[0.20680083]
#   [0.15336572]
#   [0.13046495]]]
# [[0.15018675]]
# [[[0.00469671]
#   [0.00469671]
#   [0.00469671]]]
# [[0.01932146]]
# [[[0.00143906]
#   [0.00057562]
#   [0.00028781]]]
# [[0.00346873]]
# [[[0.02547324]
#   [0.06753914]
#   [0.03715821]]]
# [[0.11575716]]
# [[[0.04295403]
#   [0.03165034]
#   [0.03240392]]]
# [[0.08427291]]
# [[[9.70873786e-05]
#   [7.76699029e-04]
#   [9.70873786e-05]]]
# [[0.00188988]]
# [[[0.12809917]
#   [0.06198347]
#   [0.02066116]]]
# [[0.07205319]]
# [[[0.46180019]
#   [0.486545  ]
#   [0.52366223]]]
# [[0.54490244]]
# [[[0.54710921]
#   [0.53747323]
#   [0.55246253]]]
# [[0.510298]]
# ...

# %%
# use middle variable to substitute y_predict in case missing the important values
a = y_predict
a
# Out:
# [array([[0.5629217]], dtype=float32),
#  array([[0.11308458]], dtype=float32),
#  array([[0.03762695]], dtype=float32),
#  array([[0.01817152]], dtype=float32),
#  array([[0.03560275]], dtype=float32),
#  array([[0.15018675]], dtype=float32),
#  array([[0.01932146]], dtype=float32),
#  array([[0.00346873]], dtype=float32),
#  array([[0.11575716]], dtype=float32),
#  array([[0.08427291]], dtype=float32),
#  array([[0.00188988]], dtype=float32),
#  array([[0.07205319]], dtype=float32),
#  array([[0.54490244]], dtype=float32),
#  array([[0.510298]], dtype=float32),
#  array([[0.44401395]], dtype=float32),
#  array([[0.36638293]], dtype=float32),
#  array([[0.15633306]], dtype=float32),
#  array([[0.05444932]], dtype=float32),
#  array([[0.51104784]], dtype=float32),
#  array([[0.34316665]], dtype=float32),
#  array([[0.58266425]], dtype=float32),
#  array([[0.60298973]], dtype=float32)]

# %%
y_predict_clean = []
for i in a:
    y_predict_clean.append(i[0])
y_predict_clean = np.array(y_predict_clean)
y_predict_clean = y_predict_clean[0:21]

X_last = df_scaled.values[-1]
X_last_scaled_real = X_last[0:21]
y_last_scaled_real = X_last[-1]
relative_error = ((y_predict_clean.T - (X_last_scaled_real))/X_last_scaled_real)
print (relative_error*100)

# %%
X = df_scaled.values
print (X.shape)
X_train = X[0:X.shape[0]-1,0:X.shape[1]-1]
y_train = X[0:X.shape[0]-1,-1]
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
# y = y.reshape(y.shape[0], 1, y.shape[1])
print (X_train.shape)
print (y_train.shape)
# Out:
# (576, 19)
# (575, 1, 18)
# (575,)

# %%
# model = Sequential()
# mymodel = model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(X_train.shape[1], X_train.shape[2])))

# %%
#building bd-lstm on forecasting the target OD
model = Sequential()
model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(LSTM(50, activation='relu'))
# model.add(LSTM(50, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
model.fit(X_train, y_train, epochs=200, verbose=0)
# history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# %%
y_predict_clean = np.array([np.delete(y_predict_clean, [3,4,10])])

# %%
X_test = (y_predict_clean)
print (X_test.shape)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
print (X_test.shape)
y_test = model.predict(X_test, verbose=0)
# Out:
# (1, 18)
# (1, 1, 18)

# %%
# Calculate the value we predicted with the real value, get the relative error
relative_error = (y_test - y_last_scaled_real)/y_last_scaled_real
print (y_test)
print (y_last_scaled_real)
print ('Relative error: ', abs(relative_error*100))
# Out:
# [[0.62124795]]
# 0.7238962859145059
# Relative error:  [[14.179976]]

# %%
# [array([[0.5629217]], dtype=float32),
#  array([[0.11308458]], dtype=float32),
#  array([[0.03762695]], dtype=float32),
#  array([[0.01817152]], dtype=float32),
#  array([[0.03560275]], dtype=float32),
#  array([[0.15018675]], dtype=float32),
#  array([[0.01932146]], dtype=float32),
#  array([[0.00346873]], dtype=float32),
#  array([[0.11575716]], dtype=float32),
#  array([[0.08427291]], dtype=float32),
#  array([[0.00188988]], dtype=float32),
#  array([[0.07205319]], dtype=float32),
#  array([[0.54490244]], dtype=float32),
#  array([[0.510298]], dtype=float32),
#  array([[0.44401395]], dtype=float32),
#  array([[0.36638293]], dtype=float32),
#  array([[0.15633306]], dtype=float32),
#  array([[0.05444932]], dtype=float32),
#  array([[0.51104784]], dtype=float32),
#  array([[0.34316665]], dtype=float32),
#  array([[0.58266425]], dtype=float32),
#  array([[0.60298973]], dtype=float32)]
